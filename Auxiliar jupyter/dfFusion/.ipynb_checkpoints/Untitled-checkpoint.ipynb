# %%
import pandas as pd

# %%
df_proyectos = pd.read_excel(
    io="/home/pablo/Proyectos/DCAyT/Streamlit/datos/Proyectos2.xlsx",
    engine="openpyxl",
    skiprows=0,
    usecols="A:Q",
    nrows=51,
    )

df_participa = pd.read_excel(
    io="/home/pablo/Proyectos/DCAyT/Streamlit/datos/Participa.xlsx",
    engine="openpyxl",
    skiprows=0,
    usecols="A:E",
    nrows=268,
    )

df_personas = pd.read_excel(
    io="/home/pablo/Proyectos/DCAyT/Streamlit/datos/Personas.xlsx",
    engine="openpyxl",
    skiprows=0,
    usecols="A:J",
    nrows=431,
    )



## SIDEBAR

# Fusionar los DataFrames para tener toda la información relevante
df_fusion = pd.merge(df_participa, df_proyectos, on="IDproyecto")
df_fusion = pd.merge(df_fusion, df_personas, on="DNI")

# %%
df_fusion.tail(5)
# Out:
#            IDproyecto       DNI         Rol  apellido  Nombre_x  \
# 0     PI-CAyT-03-2021  13521512    Director  Maccagno  Patricia
# 1     PI-CAyT-01-2023  13521512  Codirector  Maccagno  Patricia
# 2  PICyDT-2021-LGA-01  13521512    Director  Maccagno  Patricia
# 3  PICyDT-2022-LGA-01  13521512  Codirector  Maccagno  Patricia
# 4     PI-CAyT-03-2021  16891255  Codirector   Alvarez   Marcela
#
#                                             Nombre_y    Tipo  \
# 0  Sistematización de las actividades y proyectos...      PI
# 1  Relevamiento y caraterización de establecimien...      PI
# 2  Objetivos de Desarrollo Sostenible en la UNM: ...  PICYDT
# 3  Caracterización y evaluación de establecimient...  PICYDT
# 4  Sistematización de las actividades y proyectos...      PI
#
#           Convocatoria    Año                         Radicación  ...  \
# 0               PI 2021  2021  Programa de Estudios del Ambiente  ...
# 1               PI 2023  2023  Programa de Estudios del Ambiente  ...
# 2   PICYDT UNM VII 2021  2021  Programa de Estudios del Ambiente  ...
# 3  PICYDT UNM VIII 2022  2022  Programa de Estudios del Ambiente  ...
# 4               PI 2021  2021  Programa de Estudios del Ambiente  ...
#
#   Característica  Apellido               Nombre Situacion Sexo  Area  \
# 0            NaN  MACCAGNO   Patricia del Valle   Docente    F   LGA
# 1            NaN  MACCAGNO   Patricia del Valle   Docente    F   LGA
# 2            NaN  MACCAGNO   Patricia del Valle   Docente    F   LGA
# 3            NaN  MACCAGNO   Patricia del Valle   Docente    F   LGA
# 4            NaN   ÁLVAREZ    Marcela Alejandra   Docente    F   LGA
#
#     LATITUDE  LONGITUDE Título de Grado Título Posgrado
# 0 -34.637316 -58.442396      Ingeniería       Doctorado
# 1 -34.637316 -58.442396      Ingeniería       Doctorado
# 2 -34.637316 -58.442396      Ingeniería       Doctorado
# 3 -34.637316 -58.442396      Ingeniería       Doctorado
# 4 -34.603684 -58.381559   Licenciatura         Maestría
#
# [5 rows x 30 columns]

# %%
df_proyectos.tail(2)
# Out:
#    IDproyecto                    Nombre Tipo Convocatoria    Año  \
# 47       EXT3  Integración Socio Urbana  SPU      Spu 2021  2022
# 48       EXT4   Estructuras para crecer  SPU      Spu 2021  2022
#
#                                         Radicación  \
# 47  Centro de Estudios de Arquitectura y Urbanismo
# 48  Centro de Estudios de Arquitectura y Urbanismo
#
#                                                 Línea  \
# 47  Arquitectura, Tecnologías, Infraestructuras y ...
# 48  Arquitectura, Tecnologías, Infraestructuras y ...
#
#                                              Sublínea     Inicio Finalización  \
# 47  Arquitectura, Tecnologías, Infraestructuras y ... 2022-04-01   2024-04-01
# 48  Arquitectura, Tecnologías, Infraestructuras y ... 2022-04-01   2024-04-01
#
#           Estado  LATITUDE2  LONGITUDE2  \
# 47  En ejecución -34.593309  -58.624200
# 48  En ejecución -34.626966  -58.766168
#
#                                           Contraparte                  Sitio  \
# 47  Asociación Mutual de Empleo y Gestión Solidari...  https://gesol.org.ar/
# 48               Comunidad Educativa Creciendo Juntos                    NaN
#
#    Descripción Característica
# 47         NaN      Extensión
# 48         NaN      Extensión

# %%
df_personas.tail(2)
# Out:
#           DNI     Apellido      Nombre Situacion Sexo      Area  LATITUDE  \
# 428  18838268      YACUZZI       Paula   Docente    F  no posee       NaN
# 429  38428034  ZUFRIATEGUI   Macarena    Docente    F  no posee       NaN
#
#      LONGITUDE Título de Grado Título Posgrado
# 428        NaN    Arquitectura        Maestría
# 429        NaN     Profesorado        no posee

# %%
df_participa.tail(2)
# Out:
#              IDproyecto       DNI           Rol apellido    Nombre
# 266  PICyDT-2022-CED-04  25358898  Investigador  Pingaro   Gonzalo
# 267               VIN01  24126997      Director   Chorny  Fernando
