# %%
import pandas as pd

# %%
df_proyectos = pd.read_excel(
    io="/home/pablo/Proyectos/DCAyT/Streamlit/datos/Proyectos.xlsx",
    engine="openpyxl",
    skiprows=0,
    usecols="A:P",
    nrows=38,
    )

df_participa = pd.read_excel(
    io="/home/pablo/Proyectos/DCAyT/Streamlit/datos/Participa.xlsx",
    engine="openpyxl",
    skiprows=0,
    usecols="A:E",
    nrows=268,
    )

# %%
df_participa.head(3)
# Out:
#         IDproyecto       DNI           Rol  apellido    Nombre
# 0  PI-CAyT-03-2021  13521512      Director  Maccagno  Patricia
# 1  PI-CAyT-03-2021  16891255    Codirector   Alvarez   Marcela
# 2  PI-CAyT-03-2021  27794478  Investigador      Goñi  Verónica

# %%
df_proyectos.head(3)
# Out:
#         IDproyecto                                             Nombre Tipo  \
# 0  PI-CAyT-03-2021  Sistematización de las actividades y proyectos...   PI
# 1  PI-CAyT-02-2022  Identificación y caracterización de potenciale...   PI
# 2  PI-CAyT-01-2023  Relevamiento y caraterización de establecimien...   PI
#
#   Convocatoria    Año                         Radicación  \
# 0       PI 2021  2021  Programa de Estudios del Ambiente
# 1       PI 2022  2022  Programa de Estudios del Ambiente
# 2       PI 2023  2023  Programa de Estudios del Ambiente
#
#                          Línea  \
# 0                  Universidad
# 1  Ambiente y Sustentabilidad
# 2  Ambiente y Sustentabilidad
#
#                                             Sublínea     Inicio Finalización  \
# 0                             Política universitaria 2022-02-15   2023-12-29
# 1  Desarrollos para la instrumentalización de pol... 2022-05-09   2024-05-08
# ...

# %%
# Fusionar los DataFrames en función de la columna 'IDProyecto'
df_fusionado = pd.merge(df_proyectos, df_participa, on="IDproyecto")

# %%
df_fusionado.head(3)
# Out:
#         IDproyecto                                           Nombre_x Tipo  \
# 0  PI-CAyT-03-2021  Sistematización de las actividades y proyectos...   PI
# 1  PI-CAyT-03-2021  Sistematización de las actividades y proyectos...   PI
# 2  PI-CAyT-03-2021  Sistematización de las actividades y proyectos...   PI
#
#   Convocatoria    Año                         Radicación        Línea  \
# 0       PI 2021  2021  Programa de Estudios del Ambiente  Universidad
# 1       PI 2021  2021  Programa de Estudios del Ambiente  Universidad
# 2       PI 2021  2021  Programa de Estudios del Ambiente  Universidad
#
#                  Sublínea     Inicio Finalización Disposición Aprobación  \
# 0  Política universitaria 2022-02-15   2023-12-29        UNM-DCAyT 02/22
# 1  Política universitaria 2022-02-15   2023-12-29        UNM-DCAyT 02/22
# 2  Política universitaria 2022-02-15   2023-12-29        UNM-DCAyT 02/22
#
#   Expediente Acta Consejo Dpto Informe parcial  Informe final        Estado  \
# ...

# %%
### generar planilla de Personas a partir de planilla de PersonasInvestigacion y de DocentesGeneral

# %%
import pandas as pd

# %%
df_docentes = pd.read_excel(
    io="/home/pablo/Proyectos/DCAyT/Streamlit/generar_planilla_auxiliar/Docentesgeneral.xlsx",
    engine="openpyxl")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_docentes = pd.read_excel(
#       2     io="/home/pablo/Proyectos/DCAyT/Streamlit/generar_planilla_auxiliar/Docentesgeneral.xlsx")
#
# File ~/anaconda3/envs/streamlit/lib/python3.12/site-packages/pandas/io/excel/_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
# ...

# %%
df_docentes.head(5)

# %%
df_investigadores = pd.read_excel(
    io="/home/pablo/Proyectos/DCAyT/Streamlit/generar_planilla_auxiliar/Personasinvestigacion.xlsx")
